# %%
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_VISIBLE_DEVICES=1

# %%
from models.modeling_xvla import XVLA
from models.processing_xvla import XVLAProcessor

model = XVLA.from_pretrained("2toINF/X-VLA-SoftFold", trust_remote_code=True)
processor = XVLAProcessor.from_pretrained("2toINF/X-VLA-SoftFold", trust_remote_code=True)

# %%
import torch
model = model.to(device="cuda", dtype=torch.bfloat16)

# %%
import torch
from datasets.domain_config import DATA_WEIGHTS, DATA_DOMAIN_ID

# TODO
model.train(mode=False)

input_ids = processor.encode_language("do something")["input_ids"]
image_input = torch.full((1, 3, 3, 224, 224), fill_value=0.)
image_mask = torch.full((1, 3), fill_value=True)
domain_id = torch.full((1,), fill_value=DATA_DOMAIN_ID["lift2"])
proprio = torch.full((1, 20), fill_value=0.)
action = torch.full((1, 30, 20), fill_value=0.)

# %%
generate_actions = torch.compile(
    model.generate_actions, 
    fullgraph=True, 
    dynamic=False, 
    mode="max-autotune",
)

# %%
import torch
torch.set_float32_matmul_precision("high")

# %%
generate_actions(
    input_ids=input_ids.to(model.device, non_blocking=True),
    image_input=image_input.to(model.device, non_blocking=True, dtype=torch.bfloat16),
    image_mask=image_mask.to(model.device, non_blocking=True),
    domain_id=domain_id.to(model.device, non_blocking=True),
    proprio=proprio.to(model.device, non_blocking=True, dtype=torch.bfloat16),
)
# Out:
# tensor([[[-3.3594e-01, -2.5195e-01, -2.4902e-01, -2.4219e-01,  4.1992e-01,
#            1.4648e-01,  4.5312e-01,  1.1670e-01, -2.7734e-01,  4.1797e-01,
#            3.1250e-01,  4.2383e-01, -4.1992e-01, -2.3047e-01, -2.2070e-01,
#            1.0840e-01, -3.7109e-01, -1.2939e-02, -4.0430e-01,  6.0547e-01],
#          [-3.3203e-01, -2.4609e-01, -2.5195e-01, -2.4219e-01,  4.2969e-01,
#            1.4648e-01,  4.5117e-01,  1.1914e-01, -2.6953e-01,  4.1602e-01,
#            3.0273e-01,  4.3945e-01, -4.2188e-01, -2.2559e-01, -2.2168e-01,
#            1.1279e-01, -3.6328e-01, -1.0803e-02, -3.9844e-01,  6.0547e-01],
#          [-3.3398e-01, -2.3438e-01, -2.5781e-01, -2.3340e-01,  4.4141e-01,
#            1.4746e-01,  4.4727e-01,  1.2354e-01, -2.5977e-01,  4.1406e-01,
#            2.8906e-01,  4.4922e-01, -4.3164e-01, -2.1875e-01, -2.2070e-01,
#            1.0449e-01, -3.5938e-01, -1.1597e-03, -3.9648e-01,  6.0547e-01],
#          [-3.3789e-01, -2.3047e-01, -2.6562e-01, -2.3145e-01,  4.4336e-01,
#            1.4551e-01,  4.4531e-01,  1.3379e-01, -2.4707e-01,  4.1602e-01,
#            2.8320e-01,  4.5703e-01, -4.3750e-01, -2.2070e-01, -2.1777e-01,
#            1.0791e-01, -3.6133e-01,  1.6861e-03, -3.9844e-01,  6.0547e-01],
#          [-3.5547e-01, -2.2070e-01, -2.6758e-01, -2.3047e-01,  4.4922e-01,
#            1.3965e-01,  4.4336e-01,  1.4062e-01, -2.4902e-01,  4.2188e-01,
#            2.8906e-01,  4.4531e-01, -4.4531e-01, -2.1777e-01, -2.0996e-01,
#            1.1230e-01, -3.6523e-01, -8.1177e-03, -4.0234e-01,  6.0156e-01],
#          [-3.6133e-01, -2.0410e-01, -2.5781e-01, -2.2754e-01,  4.5117e-01,
#            1.3086e-01,  4.3555e-01,  1.2598e-01, -2.6172e-01,  4.2188e-01,
#            2.9297e-01,  4.2383e-01, -4.4141e-01, -2.2461e-01, -2.0215e-01,
#            1.2402e-01, -3.5742e-01, -5.5542e-03, -4.0234e-01,  6.0547e-01],
#          [-3.5742e-01, -1.9434e-01, -2.5000e-01, -2.2852e-01,  4.4336e-01,
#            1.2354e-01,  4.2188e-01,  1.0693e-01, -2.7344e-01,  4.1992e-01,
#            2.9297e-01,  4.1797e-01, -4.3555e-01, -2.2949e-01, -2.0508e-01,
#            1.1572e-01, -3.4961e-01,  7.5912e-04, -4.0039e-01,  6.0547e-01],
#          [-3.5352e-01, -1.9043e-01, -2.4707e-01, -2.3145e-01,  4.3945e-01,
#            1.2402e-01,  4.1797e-01,  9.8145e-02, -2.7930e-01,  4.1992e-01,
#            2.9102e-01,  4.1992e-01, -4.3555e-01, -2.3242e-01, -2.0605e-01,
#            1.1279e-01, -3.4570e-01, -1.1063e-03, -4.0039e-01,  6.0547e-01],
#          [-3.5352e-01, -1.9043e-01, -2.4219e-01, -2.3535e-01,  4.3359e-01,
#            1.2207e-01,  4.1797e-01,  9.5703e-02, -2.8516e-01,  4.2188e-01,
#            2.9688e-01,  4.1211e-01, -4.3750e-01, -2.3633e-01, -2.0605e-01,
#            1.1035e-01, -3.4570e-01, -4.4861e-03, -4.0039e-01,  6.0547e-01],
#          [-3.4375e-01, -1.9238e-01, -2.3242e-01, -2.3242e-01,  4.2969e-01,
#            1.2207e-01,  4.2188e-01,  9.7656e-02, -2.8711e-01,  4.2383e-01,
#            3.0469e-01,  4.0625e-01, -4.3750e-01, -2.3242e-01, -2.0801e-01,
#            1.1475e-01, -3.4375e-01,  6.0272e-04, -3.9648e-01,  6.0547e-01],
#          [-3.3789e-01, -1.9434e-01, -2.2754e-01, -2.3047e-01,  4.2773e-01,
#            1.2061e-01,  4.2383e-01,  9.9609e-02, -2.8516e-01,  4.2578e-01,
#            3.0664e-01,  4.0234e-01, -4.3555e-01, -2.3145e-01, -2.0996e-01,
#            1.1670e-01, -3.4570e-01,  1.9379e-03, -3.9453e-01,  6.0547e-01],
#          [-3.3398e-01, -1.9434e-01, -2.2754e-01, -2.3047e-01,  4.1992e-01,
#            1.2207e-01,  4.2578e-01,  1.0010e-01, -2.8516e-01,  4.2578e-01,
#            3.0859e-01,  4.0039e-01, -4.3164e-01, -2.3633e-01, -2.1289e-01,
#            1.1816e-01, -3.4766e-01,  1.7776e-03, -3.9844e-01,  6.0547e-01],
#          [-3.3398e-01, -1.9141e-01, -2.3633e-01, -2.2656e-01,  4.0820e-01,
#            1.2061e-01,  4.2969e-01,  9.9609e-02, -2.8125e-01,  4.2383e-01,
#            3.0664e-01,  4.0430e-01, -4.2383e-01, -2.3828e-01, -2.2266e-01,
#            1.1816e-01, -3.5352e-01,  7.1716e-03, -4.0234e-01,  6.0547e-01],
#          [-3.3594e-01, -1.9824e-01, -2.3828e-01, -2.2461e-01,  4.0234e-01,
#            1.2402e-01,  4.3164e-01,  1.0400e-01, -2.7539e-01,  4.2188e-01,
#            3.0273e-01,  4.0625e-01, -4.2188e-01, -2.3633e-01, -2.2656e-01,
#            1.2012e-01, -3.6328e-01,  1.0681e-02, -4.0820e-01,  6.0547e-01],
#          [-3.2812e-01, -2.0215e-01, -2.3438e-01, -2.2461e-01,  4.0039e-01,
#            1.2891e-01,  4.3164e-01,  1.1328e-01, -2.7148e-01,  4.2188e-01,
#            2.9883e-01,  4.0820e-01, -4.2188e-01, -2.3633e-01, -2.2949e-01,
#            1.1621e-01, -3.6523e-01,  3.2349e-03, -4.0625e-01,  6.0547e-01],
#          [-3.2617e-01, -2.0898e-01, -2.2949e-01, -2.2461e-01,  4.0039e-01,
#            1.3672e-01,  4.3945e-01,  1.2402e-01, -2.6953e-01,  4.2188e-01,
#            3.0078e-01,  4.1211e-01, -4.2383e-01, -2.3535e-01, -2.2656e-01,
#            1.0889e-01, -3.6914e-01, -2.0142e-03, -4.0820e-01,  6.0938e-01],
#          [-3.3203e-01, -2.1387e-01, -2.2949e-01, -2.2461e-01,  4.0430e-01,
#            1.4160e-01,  4.4336e-01,  1.2695e-01, -2.6758e-01,  4.2188e-01,
#            3.0273e-01,  4.1406e-01, -4.2578e-01, -2.3926e-01, -2.2852e-01,
#            1.0840e-01, -3.6523e-01, -4.2419e-03, -4.1406e-01,  6.0938e-01],
#          [-3.3984e-01, -2.1875e-01, -2.3047e-01, -2.2949e-01,  4.0820e-01,
#            1.4648e-01,  4.4141e-01,  1.2305e-01, -2.6953e-01,  4.1992e-01,
#            3.0273e-01,  4.1602e-01, -4.2773e-01, -2.3828e-01, -2.2754e-01,
#            1.0645e-01, -3.5938e-01, -4.9133e-03, -4.2188e-01,  6.0938e-01],
#          [-3.4375e-01, -2.1973e-01, -2.3438e-01, -2.2461e-01,  4.1406e-01,
#            1.5332e-01,  4.4336e-01,  1.1963e-01, -2.7148e-01,  4.1797e-01,
#            3.0273e-01,  4.1797e-01, -4.3164e-01, -2.3828e-01, -2.2559e-01,
#            1.0645e-01, -3.5938e-01, -4.9744e-03, -4.2773e-01,  6.0938e-01],
#          [-3.4180e-01, -2.1875e-01, -2.4121e-01, -2.1094e-01,  4.2188e-01,
#            1.6309e-01,  4.4336e-01,  1.1914e-01, -2.6367e-01,  4.1797e-01,
#            3.0078e-01,  4.2188e-01, -4.2773e-01, -2.3828e-01, -2.2852e-01,
#            1.0693e-01, -3.6914e-01, -7.4158e-03, -4.3555e-01,  6.0938e-01],
#          [-3.3594e-01, -2.2070e-01, -2.4512e-01, -2.0703e-01,  4.3164e-01,
#            1.7383e-01,  4.4727e-01,  1.2354e-01, -2.5391e-01,  4.1602e-01,
#            2.9102e-01,  4.2969e-01, -4.2188e-01, -2.4219e-01, -2.3438e-01,
#            1.0889e-01, -3.7109e-01, -9.4604e-03, -4.3164e-01,  6.0547e-01],
#          [-3.3789e-01, -2.2461e-01, -2.4414e-01, -2.0215e-01,  4.3750e-01,
#            1.7773e-01,  4.5117e-01,  1.2793e-01, -2.5391e-01,  4.1602e-01,
#            2.8516e-01,  4.3555e-01, -4.2188e-01, -2.4316e-01, -2.3535e-01,
#            1.1133e-01, -3.7109e-01, -9.2163e-03, -4.3164e-01,  6.0547e-01],
#          [-3.3789e-01, -2.2656e-01, -2.4609e-01, -1.9629e-01,  4.3945e-01,
#            1.7188e-01,  4.5898e-01,  1.3184e-01, -2.5195e-01,  4.1602e-01,
#            2.8125e-01,  4.3555e-01, -4.2188e-01, -2.3535e-01, -2.3535e-01,
#            1.0986e-01, -3.7500e-01, -5.6458e-03, -4.2773e-01,  6.0547e-01],
#          [-3.4570e-01, -2.2656e-01, -2.4902e-01, -1.9922e-01,  4.4141e-01,
#            1.6992e-01,  4.6094e-01,  1.3672e-01, -2.5391e-01,  4.1797e-01,
#            2.8125e-01,  4.3750e-01, -4.2773e-01, -2.3535e-01, -2.3242e-01,
#            1.0596e-01, -3.7891e-01, -8.2397e-03, -4.2578e-01,  6.0547e-01],
#          [-3.6133e-01, -2.2266e-01, -2.4609e-01, -2.0410e-01,  4.4531e-01,
#            1.6309e-01,  4.6289e-01,  1.3965e-01, -2.6367e-01,  4.1797e-01,
#            2.8906e-01,  4.2969e-01, -4.2773e-01, -2.3145e-01, -2.2266e-01,
#            1.0156e-01, -3.8086e-01, -1.5625e-02, -4.2383e-01,  6.0547e-01],
#          [-3.6914e-01, -2.1777e-01, -2.4316e-01, -2.0605e-01,  4.4531e-01,
#            1.5820e-01,  4.6289e-01,  1.3184e-01, -2.7148e-01,  4.1992e-01,
#            2.9492e-01,  4.2969e-01, -4.2578e-01, -2.2754e-01, -2.1680e-01,
#            1.0400e-01, -3.7500e-01, -2.1484e-02, -4.2773e-01,  6.0547e-01],
#          [-3.7500e-01, -2.1973e-01, -2.3535e-01, -2.0996e-01,  4.3945e-01,
#            1.5234e-01,  4.5898e-01,  1.2695e-01, -2.7344e-01,  4.1992e-01,
#            3.0273e-01,  4.2773e-01, -4.2188e-01, -2.2461e-01, -2.1680e-01,
#            1.0742e-01, -3.6328e-01, -2.5024e-02, -4.3164e-01,  6.0547e-01],
#          [-3.7305e-01, -2.2070e-01, -2.2461e-01, -2.1094e-01,  4.3750e-01,
#            1.5039e-01,  4.5312e-01,  1.2793e-01, -2.6758e-01,  4.2188e-01,
#            3.0664e-01,  4.1992e-01, -4.1992e-01, -2.2168e-01, -2.1289e-01,
#            1.0938e-01, -3.5156e-01, -2.7100e-02, -4.3164e-01,  6.0547e-01],
#          [-3.6914e-01, -2.2168e-01, -2.1484e-01, -2.2070e-01,  4.3555e-01,
#            1.4941e-01,  4.4531e-01,  1.3086e-01, -2.6172e-01,  4.2188e-01,
#            3.0664e-01,  4.1406e-01, -4.2773e-01, -2.1387e-01, -2.0996e-01,
#            1.1523e-01, -3.4180e-01, -2.5391e-02, -4.2578e-01,  6.0547e-01],
#          [-3.5742e-01, -2.1777e-01, -2.0801e-01, -2.2949e-01,  4.2578e-01,
#            1.4648e-01,  4.2969e-01,  1.2207e-01, -2.6562e-01,  4.2383e-01,
#            3.0469e-01,  4.0430e-01, -4.2773e-01, -2.0898e-01, -2.1094e-01,
#            1.1865e-01, -3.4180e-01, -1.2085e-02, -4.1602e-01,  6.0938e-01]]],
#        device='cuda:0', dtype=torch.bfloat16)

# %%
# %%timeit -n 10

generate_actions(
    input_ids=input_ids.to(model.device, non_blocking=True),
    image_input=image_input.to(model.device, non_blocking=True, dtype=torch.bfloat16),
    image_mask=image_mask.to(model.device, non_blocking=True),
    domain_id=domain_id.to(model.device, non_blocking=True),
    proprio=proprio.to(model.device, non_blocking=True, dtype=torch.bfloat16),
)
# Out:
# 36 ms ± 2.52 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
with torch.profiler.profile() as prof:
    generate_actions(
        input_ids=input_ids.to(model.device, non_blocking=True),
        image_input=image_input.to(model.device, non_blocking=True, dtype=torch.bfloat16),
        image_mask=image_mask.to(model.device, non_blocking=True),
        domain_id=domain_id.to(model.device, non_blocking=True),
        proprio=proprio.to(model.device, non_blocking=True, dtype=torch.bfloat16),
    )
prof.export_chrome_trace("trace.json")

# %%
actions = generate_actions(
    input_ids=input_ids.to(model.device, non_blocking=True),
    image_input=image_input.to(model.device, non_blocking=True, dtype=torch.bfloat16),
    image_mask=image_mask.to(model.device, non_blocking=True),
    domain_id=domain_id.to(model.device, non_blocking=True),
    proprio=proprio.to(model.device, non_blocking=True, dtype=torch.bfloat16),
)

# %%
# %%timeit -n 10

import io
import numpy

buffer = io.BytesIO()

numpy.save(
    buffer,
    arr=actions.to(torch.float32).numpy(force=True),
    allow_pickle=False,
)
# Out:
# The slowest run took 8.19 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1.15 ms ± 1.2 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
