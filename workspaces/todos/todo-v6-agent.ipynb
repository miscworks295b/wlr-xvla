# %%
from xvla_wlr.agent import *

# %%
xvla_agent = XVLAAgent(XVLAAgent.Config.sample())
# Out:
# Florence2ForConditionalGeneration has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.

# %%
# %%timeit -n 10
_ = xvla_agent.compute_losses(
    XVLAObservation.sample(),
    XVLAAction.sample(),
)
# Out:
# 56 ms ± 27.5 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
_ = xvla_agent.compute_actions(XVLAObservation.sample())

# %%
xvla_agent.save("/tmp/some-checkpoint-a/checkpoint.json", force=True)

# %%
xvla_agent_restored = XVLAAgent("/tmp/some-checkpoint-a/checkpoint.json")
# Out:
# Florence2ForConditionalGeneration has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.

# %%
xvla_agent_restored.learn(
    XVLAObservation.sample(),
    XVLAAction.sample(),
)
# Out:
# {'position_loss': tensor(1236.9062, grad_fn=<MulBackward0>),
#  'rotate6D_loss': tensor(22.7063, grad_fn=<MulBackward0>),
#  'gripper_loss': tensor(0.7316, grad_fn=<MulBackward0>)}

# %%
xvla_agent_restored.compute_losses(
    XVLAObservation.sample(),
    XVLAAction.sample(),
)
# Out:
# {'position_loss': tensor(1272.4218, grad_fn=<MulBackward0>),
#  'rotate6D_loss': tensor(23.1206, grad_fn=<MulBackward0>),
#  'gripper_loss': tensor(0.7371, grad_fn=<MulBackward0>)}

# %%
xvla_agent_restored.compute_actions(XVLAObservation.sample())
# Out:
# XVLAAction(ee_transforms=tensor([[[[[-0.4560,  0.8504,  0.2625, -0.3357],
#            [ 0.7264,  0.5261, -0.4422, -0.2339],
#            [-0.5142, -0.0110, -0.8576, -0.2359],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.6826, -0.6371,  0.3580,  0.3032],
#            [-0.5336,  0.0999, -0.8398,  0.4390],
#            [ 0.4993, -0.7643, -0.4082, -0.3978],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.4558,  0.8525,  0.2559, -0.3325],
#            [ 0.7269,  0.5224, -0.4458, -0.2327],
#            [-0.5137, -0.0172, -0.8578, -0.2409],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.6681, -0.6365,  0.3854,  0.3013],
#            [-0.5535,  0.0789, -0.8291,  0.4510],
#            [ 0.4973, -0.7672, -0.4050, -0.3974],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.4365,  0.8633,  0.2532, -0.3283],
#            [ 0.7442,  0.5046, -0.4376, -0.2207],
#            [-0.5056, -0.0026, -0.8628, -0.2403],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.6693, -0.6407,  0.3763,  0.2893],
#            [-0.5517,  0.0893, -0.8292,  0.4595],
#            [ 0.4977, -0.7626, -0.4132, -0.4119],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.4377,  0.8658,  0.2424, -0.3325],
#            [ 0.7527,  0.5004, -0.4279, -0.2121],
#            [-0.4918, -0.0048, -0.8707, -0.2433],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.6842, -0.6385,  0.3523,  0.2814],
#            [-0.5277,  0.1000, -0.8435,  0.4611],
#            [ 0.5034, -0.7631, -0.4054, -0.4267],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.4249,  0.8754,  0.2306, -0.3546],
#            [ 0.7582,  0.4833, -0.4377, -0.1990],
#            [-0.4946, -0.0112, -0.8691, -0.2447],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.6946, -0.6302,  0.3471,  0.2862],
#            [-0.5151,  0.0989, -0.8514,  0.4430],
#            [ 0.5022, -0.7701, -0.3933, -0.4373],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.4338,  0.8714,  0.2291, -0.3628],
#            [ 0.7394,  0.4896, -0.4623, -0.1869],
#            [-0.5150, -0.0311, -0.8566, -0.2420],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.7078, -0.6108,  0.3549,  0.2964],
#            [-0.5063,  0.0884, -0.8578,  0.4255],
#            [ 0.4926, -0.7868, -0.3718, -0.4367],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.4446,  0.8643,  0.2352, -0.3589],
#            [ 0.7162,  0.5007, -0.4862, -0.1839],
#            [-0.5380, -0.0477, -0.8416, -0.2395],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.7123, -0.6176,  0.3336,  0.3001],
#            [-0.4976,  0.1092, -0.8605,  0.4195],
#            [ 0.4950, -0.7789, -0.3851, -0.4397],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.4536,  0.8570,  0.2445, -0.3552],
#            [ 0.6980,  0.5122, -0.5004, -0.1849],
#            [-0.5541, -0.0563, -0.8306, -0.2385],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.7174, -0.6235,  0.3107,  0.3005],
#            [-0.4854,  0.1275, -0.8649,  0.4191],
#            [ 0.4997, -0.7714, -0.3941, -0.4404],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.4614,  0.8522,  0.2468, -0.3519],
#            [ 0.6892,  0.5194, -0.5051, -0.1867],
#            [-0.5586, -0.0630, -0.8270, -0.2375],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.7229, -0.6234,  0.2980,  0.3036],
#            [-0.4810,  0.1444, -0.8648,  0.4145],
#            [ 0.4960, -0.7685, -0.4042, -0.4418],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.4643,  0.8475,  0.2573, -0.3478],
#            [ 0.6895,  0.5282, -0.4956, -0.1896],
#            [-0.5559, -0.0527, -0.8296, -0.2349],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.7163, -0.6273,  0.3055,  0.3094],
#            [-0.4950,  0.1483, -0.8561,  0.4125],
#            [ 0.4918, -0.7645, -0.4168, -0.4400],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.4621,  0.8464,  0.2646, -0.3482],
#            [ 0.6940,  0.5309, -0.4862, -0.1910],
#            [-0.5520, -0.0411, -0.8328, -0.2326],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.7040, -0.6344,  0.3192,  0.3118],
#            [-0.5109,  0.1403, -0.8481,  0.4133],
#            [ 0.4933, -0.7601, -0.4229, -0.4353],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.4608,  0.8440,  0.2743, -0.3462],
#            [ 0.6985,  0.5356, -0.4745, -0.1919],
#            [-0.5474, -0.0270, -0.8364, -0.2326],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.6987, -0.6353,  0.3290,  0.3141],
#            [-0.5210,  0.1367, -0.8426,  0.4124],
#            [ 0.4903, -0.7601, -0.4264, -0.4322],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.4578,  0.8443,  0.2785, -0.3483],
#            [ 0.7130,  0.5358, -0.4524, -0.1907],
#            [-0.5312, -0.0086, -0.8472, -0.2376],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.6881, -0.6435,  0.3352,  0.3116],
#            [-0.5328,  0.1345, -0.8355,  0.4180],
#            [ 0.4925, -0.7535, -0.4354, -0.4246],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.4518,  0.8447,  0.2869, -0.3507],
#            [ 0.7203,  0.5352, -0.4413, -0.1921],
#            [-0.5263,  0.0073, -0.8503, -0.2389],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.6778, -0.6463,  0.3505,  0.3084],
#            [-0.5475,  0.1254, -0.8274,  0.4141],
#            [ 0.4908, -0.7527, -0.4388, -0.4147],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.4505,  0.8456,  0.2865, -0.3481],
#            [ 0.7162,  0.5338, -0.4495, -0.1968],
#            [-0.5330,  0.0027, -0.8461, -0.2399],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.6877, -0.6473,  0.3289,  0.3113],
#            [-0.5319,  0.1408, -0.8350,  0.4123],
#            [ 0.4941, -0.7492, -0.4411, -0.4119],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.4445,  0.8476,  0.2897, -0.3462],
#            [ 0.7195,  0.5305, -0.4481, -0.2024],
#            [-0.5335,  0.0092, -0.8457, -0.2388],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.6915, -0.6491,  0.3171,  0.3102],
#            [-0.5203,  0.1430, -0.8419,  0.4131],
#            [ 0.5011, -0.7472, -0.4366, -0.4096],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.4386,  0.8502,  0.2911, -0.3458],
#            [ 0.7243,  0.5262, -0.4456, -0.2062],
#            [-0.5320,  0.0154, -0.8466, -0.2374],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.6847, -0.6525,  0.3247,  0.3080],
#            [-0.5221,  0.1283, -0.8432,  0.4156],
#            [ 0.5085, -0.7469, -0.4285, -0.4091],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.4368,  0.8511,  0.2911, -0.3437],
#            [ 0.7286,  0.5246, -0.4405, -0.2089],
#            [-0.5276,  0.0197, -0.8493, -0.2355],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.6824, -0.6525,  0.3296,  0.3043],
#            [-0.5165,  0.1113, -0.8490,  0.4168],
#            [ 0.5173, -0.7496, -0.4130, -0.4095],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.4259,  0.8554,  0.2948, -0.3406],
#            [ 0.7389,  0.5168, -0.4324, -0.2105],
#            [-0.5222,  0.0337, -0.8522, -0.2347],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.6867, -0.6472,  0.3310,  0.3000],
#            [-0.5119,  0.1073, -0.8523,  0.4175],
#            [ 0.5161, -0.7547, -0.4050, -0.4103],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.4054,  0.8629,  0.3018, -0.3323],
#            [ 0.7565,  0.5020, -0.4191, -0.2134],
#            [-0.5132,  0.0584, -0.8563, -0.2351],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.6856, -0.6511,  0.3256,  0.2945],
#            [-0.5096,  0.1099, -0.8534,  0.4217],
#            [ 0.5198, -0.7510, -0.4071, -0.4161],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.3950,  0.8667,  0.3046, -0.3290],
#            [ 0.7693,  0.4933, -0.4060, -0.2166],
#            [-0.5021,  0.0739, -0.8616, -0.2365],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.6899, -0.6423,  0.3339,  0.2894],
#            [-0.5121,  0.1069, -0.8523,  0.4280],
#            [ 0.5117, -0.7589, -0.4027, -0.4153],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.3838,  0.8691,  0.3120, -0.3315],
#            [ 0.7764,  0.4866, -0.4006, -0.2222],
#            [-0.5000,  0.0885, -0.8615, -0.2371],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.6948, -0.6353,  0.3370,  0.2878],
#            [-0.5119,  0.1078, -0.8523,  0.4340],
#            [ 0.5051, -0.7647, -0.4001, -0.4161],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.3812,  0.8682,  0.3178, -0.3318],
#            [ 0.7799,  0.4866, -0.3938, -0.2281],
#            [-0.4965,  0.0977, -0.8625, -0.2373],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.6922, -0.6445,  0.3247,  0.2858],
#            [-0.5088,  0.1168, -0.8529,  0.4390],
#            [ 0.5118, -0.7556, -0.4087, -0.4178],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.3841,  0.8693,  0.3111, -0.3391],
#            [ 0.7767,  0.4864, -0.4003, -0.2251],
#            [-0.4993,  0.0879, -0.8620, -0.2362],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.6968, -0.6479,  0.3078,  0.2868],
#            [-0.4924,  0.1199, -0.8621,  0.4357],
#            [ 0.5216, -0.7522, -0.4026, -0.4231],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.3874,  0.8730,  0.2963, -0.3475],
#            [ 0.7685,  0.4834, -0.4193, -0.2208],
#            [-0.5093,  0.0653, -0.8581, -0.2325],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.7006, -0.6485,  0.2978,  0.2899],
#            [-0.4833,  0.1241, -0.8666,  0.4325],
#            [ 0.5250, -0.7511, -0.4003, -0.4290],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.3763,  0.8790,  0.2929, -0.3598],
#            [ 0.7669,  0.4729, -0.4339, -0.2150],
#            [-0.5199,  0.0614, -0.8520, -0.2296],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.6909, -0.6580,  0.2994,  0.2917],
#            [-0.4915,  0.1239, -0.8620,  0.4265],
#            [ 0.5301, -0.7427, -0.4091, -0.4287],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.3671,  0.8825,  0.2942, -0.3741],
#            [ 0.7670,  0.4660, -0.4411, -0.2107],
#            [-0.5263,  0.0637, -0.8479, -0.2192],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.6931, -0.6482,  0.3154,  0.3002],
#            [-0.4874,  0.0990, -0.8675,  0.4223],
#            [ 0.5311, -0.7550, -0.3845, -0.4277],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.3610,  0.8842,  0.2965, -0.3790],
#            [ 0.7717,  0.4617, -0.4373, -0.2068],
#            [-0.5235,  0.0709, -0.8490, -0.2027],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.6989, -0.6302,  0.3381,  0.3069],
#            [-0.4883,  0.0750, -0.8695,  0.4237],
#            [ 0.5226, -0.7728, -0.3602, -0.4292],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.3718,  0.8823,  0.2887, -0.3786],
#            [ 0.7657,  0.4673, -0.4419, -0.2034],
#            [-0.5248,  0.0567, -0.8493, -0.1823],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.7019, -0.6203,  0.3500,  0.3083],
#            [-0.4892,  0.0628, -0.8699,  0.4211],
#            [ 0.5177, -0.7818, -0.3475, -0.4347],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]],
#
#
#          [[[-0.4012,  0.8671,  0.2951, -0.3675],
#            [ 0.7542,  0.4956, -0.4308, -0.2010],
#            [-0.5198,  0.0498, -0.8528, -0.1728],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#           [[-0.6935, -0.6223,  0.3632,  0.3074],
#            [-0.5089,  0.0662, -0.8583,  0.4193],
#            [ 0.5100, -0.7800, -0.3625, -0.4270],
#            [ 0.0000,  0.0000,  0.0000,  1.0000]]]]]), ee_gripper_vals=tensor([[[[0.4145],
#           [0.6031]],
#
#          [[0.4140],
#           [0.6031]],
#
#          [[0.4131],
#           [0.6049]],
#
#          [[0.4173],
#           [0.6064]],
#
#          [[0.4225],
#           [0.6056]],
#
#          [[0.4236],
#           [0.6063]],
#
#          [[0.4217],
#           [0.6060]],
#
#          [[0.4216],
#           [0.6046]],
#
#          [[0.4224],
#           [0.6045]],
#
#          [[0.4242],
#           [0.6041]],
#
#          [[0.4245],
#           [0.6031]],
#
#          [[0.4239],
#           [0.6028]],
#
#          [[0.4209],
#           [0.6039]],
#
#          [[0.4185],
#           [0.6040]],
#
#          [[0.4201],
#           [0.6042]],
#
#          [[0.4217],
#           [0.6053]],
#
#          [[0.4221],
#           [0.6056]],
#
#          [[0.4207],
#           [0.6065]],
#
#          [[0.4196],
#           [0.6067]],
#
#          [[0.4186],
#           [0.6065]],
#
#          [[0.4179],
#           [0.6057]],
#
#          [[0.4183],
#           [0.6052]],
#
#          [[0.4194],
#           [0.6054]],
#
#          [[0.4202],
#           [0.6058]],
#
#          [[0.4209],
#           [0.6065]],
#
#          [[0.4228],
#           [0.6064]],
#
#          [[0.4211],
#           [0.6041]],
#
#          [[0.4209],
#           [0.6028]],
#
#          [[0.4224],
#           [0.6020]],
#
#          [[0.4233],
#           [0.6022]]]]))
